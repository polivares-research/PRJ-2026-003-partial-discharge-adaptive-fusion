# %%
from partial_discharge_adaptive_fusion.protocol import assert_protocol_frozen, load_experiment_config
CONFIG = load_experiment_config('configs/experiments/two-dataset-confirmatory-v2-batch4-localraw.yaml')
assert_protocol_frozen(CONFIG)
assert CONFIG['experts']['batch_size'] == CONFIG['experts']['inference_batch_size'] == 4
print('Using config:', CONFIG['config_version'])
# Out:
# Using config: two-dataset-confirmatory-v2-batch4-localraw

# %% [markdown]
# # Publication figures
#
# **Objective.** Generate compact, publication-quality figures from frozen result files.
#
# **Inputs.** Final v2-batch4 metrics, reliability tables, disagreement summaries and predictions.
#
# **Outputs.** MCC comparisons, Delta MCC per seed, reliability calibration, disagreement and oracle-headroom figures.
#
# **Experimental role.** Visualization only.
#
# **Leakage constraints.** No figure may be used to select a model or revise the protocol; captions must include dataset, split and v2 `config_version`.

# %%
import matplotlib.pyplot as plt

plt.rcParams.update({'figure.dpi': 120, 'axes.titlesize': 11})
print('Figures must be generated from frozen CSV/Parquet/JSON outputs.')
# Out:
# Figures must be generated from frozen CSV/Parquet/JSON outputs.

# %% [markdown]
# ## Findings and handoff
#
# Figures are descriptive representations of the final statistical analysis and must include dataset, split and seed context in captions.
#
# **Next stage:** archive the frozen configuration, tables, figures and provenance.
