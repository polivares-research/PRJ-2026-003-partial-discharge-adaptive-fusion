# %% [markdown]
# ## Final-result gate
#
# Only the frozen representation-aware v3 outputs can support the scientific verdict. The five registered verdict labels are applied after independent five-seed dataset-specific analyses.

# %%
from partial_discharge_adaptive_fusion.protocol import assert_protocol_frozen, load_experiment_config
CONFIG = load_experiment_config('configs/experiments/two-dataset-confirmatory-v3-windowed-localraw.yaml')
assert_protocol_frozen(CONFIG)
assert CONFIG['experts']['batch_size'] == CONFIG['experts']['inference_batch_size'] == 4
print('Using config:', CONFIG['config_version'])
# Out:
# Using config: two-dataset-confirmatory-v3-windowed-localraw

# %% [markdown]
# # Final publication-oriented results
#
# **Objective.** Render final tables and interpretations from frozen experiment outputs only.
#
# **Inputs.** v3-windowed dataset-specific metrics, confidence intervals, manifests and provenance.
#
# **Outputs.** Publication tables, captions, cross-dataset verdict and limitations.
#
# **Experimental role.** Reporting only; no tuning.
#
# **Leakage constraints.** This notebook cannot alter splits, models, thresholds, weights or statistical criteria and must report the v2 `config_version`.

# %%
from pathlib import Path

print('Load only frozen results from results/runs and reports/metrics.')
print('Primary metric: MCC; retain seed variability and paired intervals.')
assert not any(Path('notebooks').rglob('*.nbconvert.ipynb'))
# Out:
# Load only frozen results from results/runs and reports/metrics.
# Primary metric: MCC; retain seed variability and paired intervals.

# %% [markdown]
# ## Findings and handoff
#
# Only conclusions supported by both dataset-specific evidence and the registered statistical rules may be stated.
#
# **Next stage:** create final figures without introducing new analyses.
