# %% [markdown]
# # Temporal and spectrogram experts
#
# This English notebook is a reporting wrapper. Heavy computation is performed by `scripts/run_temporal_spectrogram_cross_dataset_diagnostic.py`; this wrapper only reads the generated development artifacts. MATLAB is restricted to Tr1/Va1 and VSB is restricted to the forensic development pool.

# %%
from pathlib import Path
import pandas as pd
root = Path('results/audits/temporal-spectrogram-cross-dataset')
metrics = pd.read_csv(root / 'metrics.csv') if (root / 'metrics.csv').is_file() else pd.DataFrame()
metrics
