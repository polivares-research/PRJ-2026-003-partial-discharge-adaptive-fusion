# %% [markdown]
# # V5 pulse-aware expert gate
#
# This notebook is a thin wrapper around cache preparation, expert training, and the seed-42--44 gate. Gate records remain parent-signal level and holdouts stay locked until a frozen protocol exists.

# %%
from pathlib import Path
CONFIG = Path('configs/experiments/two-dataset-confirmatory-v5-pulse-aware-localraw.yaml')
print(f'V5 configuration: {CONFIG}')
print('Run prepare_v5_pulse_cache.py before supplying candidate seed records to run_v5_development_gate.py.')
