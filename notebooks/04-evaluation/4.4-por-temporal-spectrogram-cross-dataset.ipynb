# %% [markdown]
# # Cross-dataset temporal versus spectrogram diagnostic
#
# This notebook is an English reporting wrapper around the staged runner outputs. It reports MCC, overlap/oracle diagnostics, and the registered verdict. It does not run CWT, open holdouts, or create adaptive fusion.

# %%
from pathlib import Path
import json
report = Path('reports/audits/temporal_spectrogram_cross_dataset_diagnostic.json')
summary = json.loads(report.read_text()) if report.is_file() else {'status': 'not executed'}
summary
