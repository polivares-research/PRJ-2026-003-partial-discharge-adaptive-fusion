# %% [markdown]
# # Current-expert adaptive fusion evaluation
#
# This notebook reports the staged runner outputs. It does not train models or open holdouts. The primary contrasts are best fixed fusion versus the OOF-selected best individual, adaptive versus best fixed, and adaptive versus best individual.

# %%
from pathlib import Path
import json
import pandas as pd

ROOT = Path.cwd()
REPORT = ROOT / 'reports/audits/current_expert_adaptive_fusion.md'
SUMMARY = ROOT / 'reports/audits/current_expert_adaptive_fusion.json'
summary = json.loads(SUMMARY.read_text())
print(summary['verdict'])
pd.DataFrame(summary['metrics'])

# %% [markdown]
# Interpretation must keep MATLAB and VSB separate. If a dataset did not pass development eligibility, its confirmatory holdout remains locked and its result is not a negative holdout result.
