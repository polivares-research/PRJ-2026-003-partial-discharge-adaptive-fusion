# %% [markdown]
# # Presupuesto de memoria GPU. Esta notebook calcula simbólicamente la memoria de los expertos congelados. No mueve modelos a CUDA, no ejecuta inferencia y no entrena. Compara batch 128 de v1 con batch físico 4 de v2.

# %%
import sys; from pathlib import Path; ROOT = next(path for path in [Path.cwd(), *Path.cwd().parents] if (path / 'configs').is_dir() and (path / 'src').is_dir()); sys.path.insert(0, str(ROOT)); sys.path.insert(0, str(ROOT / 'src')); from scripts.estimate_vram import estimate_all;
for batch_size in (128, 4):
    cases = estimate_all(batch_size=batch_size)['cases']
    print('BATCH', batch_size, [(case['case'], round(case['model_payload_plus_three_x_activation_gib'], 3)) for case in cases])

# %% [markdown]
# ## Interpretación. El presupuesto no incluye completamente el contexto CUDA ni workspaces específicos del driver. La configuración v1 mantiene batch 128 para una GPU grande; la configuración v2-batch4 aplica batch físico 4 a ambos expertos y datasets. No se debe cambiar batch, resampling ni ventanas dentro de una ejecución congelada.
