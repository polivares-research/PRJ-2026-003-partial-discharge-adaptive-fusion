# %% [markdown]
# # Current-expert adaptive fusion
#
# This notebook is a lightweight reporting wrapper. Heavy computation is performed by `scripts/run_current_expert_adaptive_fusion.py`. Historical metrics are context only; active calibration and fusion use current development predictions.

# %%
from pathlib import Path
import json
import pandas as pd

ROOT = Path.cwd()
OUTPUT = ROOT / 'results/audits/current-expert-adaptive-fusion'
gate = json.loads((OUTPUT / 'development_gate.json').read_text())
metrics = pd.read_csv(OUTPUT / 'development_metrics.csv')
display(metrics)
gate

# %% [markdown]
# The development gate is dataset-specific. MATLAB uses clean fixed-epoch temporal predictions; VSB uses the frozen current temporal and global-spectrogram artifacts. Holdouts remain closed until the freeze stage passes.
