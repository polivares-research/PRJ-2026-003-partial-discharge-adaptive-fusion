# %% [markdown]
# # Dataset inventory
#
# **Objective.** Resolve and document both partial-discharge datasets from the repository-local `data/raw` layout.
#
# **Inputs.** `PD_RAW_DATA_ROOT` and the manually transferred raw files.
#
# **Outputs.** Dataset IDs, versions, return types, metadata and runtime provenance.
#
# **Experimental role.** First data-access gate; no model training.
#
# **Leakage constraints.** Do not load `Te2.mat`; do not copy raw data; do not infer dataset IDs from filesystem paths.

# %%
from partial_discharge_adaptive_fusion.config import runtime_info
from partial_discharge_adaptive_fusion.dataset import resolve_dataset

print(runtime_info().as_dict())
for dataset_id, version in [
    ('engineering-partial-discharge-noise-signals', 'v1'),
    ('engineering-vsb-power-line-fault-detection', '2018-kaggle-snapshot'),
]: 
    dataset = resolve_dataset(dataset_id, version)
    print(dataset.dataset_id, dataset.version, type(dataset.handle).__name__)
    print(dataset.metadata)
# Out:
# {'python': '3.11.16 (main, Sep  2 2026, 23:39:52) [GCC 15.3.0]', 'platform': 'Linux-6.17.0-35-generic-x86_64-with-glibc2.39', 'torch': '2.11.0+cu128', 'torch_cuda': '12.8', 'cuda_available': True, 'gpu_name': 'NVIDIA RTX PRO 6000 Blackwell Max-Q Workstation Edition', 'numpy': '2.4.6', 'pandas': '3.0.5', 'scipy': '1.17.1', 'sklearn': '1.9.0', 'pyarrow': '25.0.0'}
# engineering-partial-discharge-noise-signals v1 LocalDatasetSource
# {'dataset_id': 'engineering-partial-discharge-noise-signals', 'versions': {'current_version': 'v1'}, 'source': {'type': 'local_raw', 'root_environment_variable': 'PD_RAW_DATA_ROOT'}, 'files': [{'file_id': 'pd-noise-tr0', 'relative_path': 'dataset-pd-noise/Tr0.mat', 'required': False}, {'file_id': 'pd-noise-va0', 'relative_path': 'dataset-pd-noise/Va0.mat', 'required': False}, {'file_id': 'pd-noise-te0', 'relative_path': 'dataset-pd-noise/Te0.mat', 'required': False}, {'file_id': 'pd-noise-tr1', 'relative_path': 'dataset-pd-noise/Tr1.mat', 'required': True}, {'file_id': 'pd-noise-va1', 'relative_path': 'dataset-pd-noise/Va1.mat', 'required': True}, {'file_id': 'pd-noise-te1', 'relative_path': 'dataset-pd-noise/Te1.mat', 'required': True}, {'file_id': 'pd-noise-te2', 'relative_path': 'dataset-pd-noise/Te2.mat', 'required': True}, {'file_id': 'pd-noise-readme', 'relative_path': 'dataset-pd-noise/readme.txt', 'required': False}, {'file_id': 'pd-noise-figshare-metadata', 'relative_path': 'dataset-pd-noise/24033225.xml', 'required': False}, {'file_id': 'pd-noise-paper', 'relative_path': 'dataset-pd-noise/1-s2.0-S095219762400232X-main.pdf', 'required': False}]}
# engineering-vsb-power-line-fault-detection 2018-kaggle-snapshot LocalDatasetSource
# {'dataset_id': 'engineering-vsb-power-line-fault-detection', 'versions': {'current_version': '2018-kaggle-snapshot'}, 'source': {'type': 'local_raw', 'root_environment_variable': 'PD_RAW_DATA_ROOT'}, 'files': [{'file_id': 'vsb-train-parquet', 'relative_path': 'dataset-vsb-power-line-fault-detection/train.parquet', 'required': True}, {'file_id': 'vsb-test-parquet', 'relative_path': 'dataset-vsb-power-line-fault-detection/test.parquet', 'required': False}, {'file_id': 'vsb-train-parquet-zip', 'relative_path': 'dataset-vsb-power-line-fault-detection/train.parquet.zip', 'required': False}, {'file_id': 'vsb-test-parquet-zip', 'relative_path': 'dataset-vsb-power-line-fault-detection/test.parquet.zip', 'required': False}, {'file_id': 'vsb-metadata-train', 'relative_path': 'dataset-vsb-power-line-fault-detection/metadata_train.csv', 'required': True}, {'file_id': 'vsb-metadata-test', 'relative_path': 'dataset-vsb-power-line-fault-detection/metadata_test.csv', 'required': False}, {'file_id': 'vsb-sample-submission', 'relative_path': 'dataset-vsb-power-line-fault-detection/sample_submission.csv', 'required': False}, {'file_id': 'vsb-source-metadata', 'relative_path': 'dataset-vsb-power-line-fault-detection/source_metadata.yaml', 'required': False}], 'scope': {'temporal_scope': {'sampling_frequency': 40000000}}}

# %% [markdown]
# ## Findings and handoff
#
# Record the local adapter's exact identifiers and file metadata in the protocol manifest. Supported conclusions are limited to data resolution and metadata. No scientific performance conclusion is supported here.
#
# **Next stage:** run the MATLAB and VSB audits from the same local raw-data root; no ResearchHub Atlas or `researchdata` installation is required.
