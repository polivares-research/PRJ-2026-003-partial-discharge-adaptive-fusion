# %% [markdown]
# # V5 pulse and provenance audit
#
# This wrapper audits local `data/raw`, VSB group metadata, cycle coverage, and the literature-inspired signal-level adaptation. It does not open VSB holdout data or MATLAB Te2.

# %%
from pathlib import Path
import subprocess, sys
subprocess.run([sys.executable, 'scripts/audit_v5_dualcycon_reproduction.py'], check=True)
